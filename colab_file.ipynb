# %%
# !pip -q install --upgrade transformers accelerate bitsandbytes einops
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 20.2 MB/s eta 0:00:00

# %% [markdown]
# Subir zip

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a86ce8eb-f658-42ea-a5d6-7afbeb2dd640" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a86ce8eb-f658-42ea-a5d6-7afbeb2dd640">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# for replacement

# %%
# !rm -rf planning/
# !rm -f Lab4-DL.zip Examples.json Task.json submission.json .gitignore README.md Session7_0_LLM.ipynb

# %%
# !unzip -q Lab4-DL.zip

# %%
# !python -m py_compile planning/student_agent.py planning/submit.py planning/llm_engine.py

# %%
# %%time
# !python planning/dev_test.py
# Out:
# ...
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 399/399 [01:10<00:00,  5.63it/s]
# Cargando dataset de desarrollo: Examples.json
# --------------------------------------------------
# Evaluando Tarea ID: task_6a4ed4586d (Longitud optima: 4)
# [transformers] The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Plan Generado: ['(attack a)', '(overcome a c)', '(attack b)', '(overcome b a)']
# Score obtenido: 10.0 / 10.0
#
# Evaluando Tarea ID: task_b9a95877e2 (Longitud optima: 4)
# Plan Generado: ['(overcome a c)', '(attack c)', '(overcome c a)']
# Score obtenido: 0.0 / 10.0
#
# ...

# %%
# %%time
# !python planning/submit.py
# Out:
# ...
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 399/399 [01:11<00:00,  5.61it/s]
# Iniciando ejecucion sobre: Task.json
# Procesando caso 1/50 (ID: task_f6c3f52f55)...
# [transformers] The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Procesando caso 2/50 (ID: task_07a18910c7)...
# Procesando caso 3/50 (ID: task_cbe2649f6b)...
# Procesando caso 4/50 (ID: task_4f181b1e7e)...
# Procesando caso 5/50 (ID: task_9f39e7f413)...
# Procesando caso 6/50 (ID: task_a51e02706c)...
# Procesando caso 7/50 (ID: task_8a763f838b)...
# Procesando caso 8/50 (ID: task_4d92dfa4d1)...
# ...

# %%
import json

data = json.load(open("submission.json"))

print("Cantidad:", len(data))
print("Campos correctos:", all(
    set(x.keys()) == {"assembly_task_id", "complexity_level", "target_action_sequence"}
    for x in data
))
print("Complexity correcto:", all(
    x["complexity_level"] == len(x["target_action_sequence"])
    for x in data
))
print(data[0])
# Out:
# Cantidad: 50
# Campos correctos: True
# Complexity correcto: True
# {'assembly_task_id': 'task_f6c3f52f55', 'complexity_level': 3, 'target_action_sequence': ['(mount_node red orange)', '(mount_node blue red)', '(mount_node yellow blue)']}

# %%
from google.colab import files
files.download("submission.json")
